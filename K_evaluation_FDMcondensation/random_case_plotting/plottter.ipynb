# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt


perc1_k50_mu = pd.read_csv('modular_unlearning_stats_0.01_50_arbitrary_uniform.csv')
perc1_k50_cf= pd.read_csv('catastrophic_unlearning_stats_0.01_50_arbitrary_uniform.csv')
perc1_k50_r= pd.read_csv('retraining_unlearning_stats_0.01_50_arbitrary_uniform.csv')

perc1_k500_mu = pd.read_csv('modular_unlearning_stats_0.01_500_arbitrary_uniform.csv')
perc1_k500_cf= pd.read_csv('catastrophic_unlearning_stats_0.01_500_arbitrary_uniform.csv')
perc1_k500_r= pd.read_csv('retraining_unlearning_stats_0.01_500_arbitrary_uniform.csv')

perc1_k1000_mu = pd.read_csv('modular_unlearning_stats_0.01_1000_arbitrary_uniform.csv')
perc1_k1000_cf= pd.read_csv('catastrophic_unlearning_stats_0.01_1000_arbitrary_uniform.csv')
perc1_k1000_r= pd.read_csv('retraining_unlearning_stats_0.01_1000_arbitrary_uniform.csv')

perc10_k50_mu = pd.read_csv('modular_unlearning_stats_0.1_50_arbitrary_uniform.csv')
perc10_k50_cf= pd.read_csv('catastrophic_unlearning_stats_0.1_50_arbitrary_uniform.csv')
perc10_k50_r= pd.read_csv('retraining_unlearning_stats_0.1_50_arbitrary_uniform.csv')

perc10_k500_mu = pd.read_csv('modular_unlearning_stats_0.1_500_arbitrary_uniform.csv')
perc10_k500_cf= pd.read_csv('catastrophic_unlearning_stats_0.1_500_arbitrary_uniform.csv')
perc10_k500_r= pd.read_csv('retraining_unlearning_stats_0.1_500_arbitrary_uniform.csv')

perc10_k1000_mu = pd.read_csv('modular_unlearning_stats_0.1_1000_arbitrary_uniform.csv')
perc10_k1000_cf= pd.read_csv('catastrophic_unlearning_stats_0.1_1000_arbitrary_uniform.csv')
perc10_k1000_r= pd.read_csv('retraining_unlearning_stats_0.1_1000_arbitrary_uniform.csv')

perc50_k50_mu = pd.read_csv('modular_unlearning_stats_0.5_50_arbitrary_uniform.csv')
perc50_k50_cf= pd.read_csv('catastrophic_unlearning_stats_0.5_50_arbitrary_uniform.csv')
perc50_k50_r= pd.read_csv('retraining_unlearning_stats_0.5_50_arbitrary_uniform.csv')

perc50_k500_mu = pd.read_csv('modular_unlearning_stats_0.5_500_arbitrary_uniform.csv')
perc50_k500_cf= pd.read_csv('catastrophic_unlearning_stats_0.5_500_arbitrary_uniform.csv')
perc50_k500_r= pd.read_csv('retraining_unlearning_stats_0.5_500_arbitrary_uniform.csv')

perc50_k1000_mu = pd.read_csv('modular_unlearning_stats_0.5_1000_arbitrary_uniform.csv')
perc50_k1000_cf= pd.read_csv('catastrophic_unlearning_stats_0.5_1000_arbitrary_uniform.csv')
perc50_k1000_r= pd.read_csv('retraining_unlearning_stats_0.5_1000_arbitrary_uniform.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn styling
sns.set(style="whitegrid")

# Data
x = [50, 500, 1000]
Y_MU=[]
Y_CF=[]
Y_R=[]

y_mu = [perc1_k50_mu['retain_acc'].mean(), perc1_k500_mu['retain_acc'].mean(), perc1_k1000_mu['retain_acc'].mean()]
y_cf = [perc1_k50_cf['retain_acc'].mean(), perc1_k500_cf['retain_acc'].mean(), perc1_k1000_cf['retain_acc'].mean()]
y_r = [perc1_k50_r['retain_acc'].mean(), perc1_k500_r['retain_acc'].mean(), perc1_k1000_r['retain_acc'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)


y_mu = [perc10_k50_mu['retain_acc'].mean(), perc10_k500_mu['retain_acc'].mean(), perc10_k1000_mu['retain_acc'].mean()]
y_cf = [perc10_k50_cf['retain_acc'].mean(), perc10_k500_cf['retain_acc'].mean(), perc10_k1000_cf['retain_acc'].mean()]
y_r = [perc10_k50_r['retain_acc'].mean(), perc10_k500_r['retain_acc'].mean(), perc10_k1000_r['retain_acc'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)

y_mu = [perc50_k50_mu['retain_acc'].mean(), perc50_k500_mu['retain_acc'].mean(), perc50_k1000_mu['retain_acc'].mean()]
y_cf = [perc50_k50_cf['retain_acc'].mean(), perc50_k500_cf['retain_acc'].mean(), perc50_k1000_cf['retain_acc'].mean()]
y_r = [perc50_k50_r['retain_acc'].mean(), perc50_k500_r['retain_acc'].mean(), perc50_k1000_r['retain_acc'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)


y_mu = [perc1_k50_mu['forget_acc'].mean(), perc1_k500_mu['forget_acc'].mean(), perc1_k1000_mu['forget_acc'].mean()]
y_cf = [perc1_k50_cf['forget_acc'].mean(), perc1_k500_cf['forget_acc'].mean(), perc1_k1000_cf['forget_acc'].mean()]
y_r = [perc1_k50_r['forget_acc'].mean(), perc1_k500_r['forget_acc'].mean(), perc1_k1000_r['forget_acc'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)

y_mu = [perc10_k50_mu['forget_acc'].mean(), perc10_k500_mu['forget_acc'].mean(), perc10_k1000_mu['forget_acc'].mean()]
y_cf = [perc10_k50_cf['forget_acc'].mean(), perc10_k500_cf['forget_acc'].mean(), perc10_k1000_cf['forget_acc'].mean()]
y_r = [perc10_k50_r['forget_acc'].mean(), perc10_k500_r['forget_acc'].mean(), perc10_k1000_r['forget_acc'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)

y_mu = [perc50_k50_mu['forget_acc'].mean(), perc50_k500_mu['forget_acc'].mean(), perc50_k1000_mu['forget_acc'].mean()]
y_cf = [perc50_k50_cf['forget_acc'].mean(), perc50_k500_cf['forget_acc'].mean(), perc50_k1000_cf['forget_acc'].mean()]
y_r = [perc50_k50_r['forget_acc'].mean(), perc50_k500_r['forget_acc'].mean(), perc50_k1000_r['forget_acc'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)

y_mu = [perc1_k50_mu['mia_score'].mean(), perc1_k500_mu['mia_score'].mean(), perc1_k1000_mu['mia_score'].mean()]
y_cf = [perc1_k50_cf['mia_score'].mean(), perc1_k500_cf['mia_score'].mean(), perc1_k1000_cf['mia_score'].mean()]
y_r = [perc1_k50_r['mia_score'].mean(), perc1_k500_r['mia_score'].mean(), perc1_k1000_r['mia_score'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)

y_mu = [perc10_k50_mu['mia_score'].mean(), perc10_k500_mu['mia_score'].mean(), perc10_k1000_mu['mia_score'].mean()]
y_cf = [perc10_k50_cf['mia_score'].mean(), perc10_k500_cf['mia_score'].mean(), perc10_k1000_cf['mia_score'].mean()]
y_r = [perc10_k50_r['mia_score'].mean(), perc10_k500_r['mia_score'].mean(), perc10_k1000_r['mia_score'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)

y_mu = [perc50_k50_mu['mia_score'].mean(), perc50_k500_mu['mia_score'].mean(), perc50_k1000_mu['mia_score'].mean()]
y_cf = [perc50_k50_cf['mia_score'].mean(), perc50_k500_cf['mia_score'].mean(), perc50_k1000_cf['mia_score'].mean()]
y_r = [perc50_k50_r['mia_score'].mean(), perc50_k500_r['mia_score'].mean(), perc50_k1000_r['mia_score'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)


y_mu = [perc1_k50_mu['unlearning_time'].mean(), perc1_k500_mu['unlearning_time'].mean(), perc1_k1000_mu['unlearning_time'].mean()]
y_cf = [perc1_k50_cf['unlearning_time'].mean(), perc1_k500_cf['unlearning_time'].mean(), perc1_k1000_cf['unlearning_time'].mean()]
y_r = [perc1_k50_r['unlearning_time'].mean(), perc1_k500_r['unlearning_time'].mean(), perc1_k1000_r['unlearning_time'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)

y_mu = [perc10_k50_mu['unlearning_time'].mean(), perc10_k500_mu['unlearning_time'].mean(), perc10_k1000_mu['unlearning_time'].mean()]
y_cf = [perc10_k50_cf['unlearning_time'].mean(), perc10_k500_cf['unlearning_time'].mean(), perc10_k1000_cf['unlearning_time'].mean()]
y_r = [perc10_k50_r['unlearning_time'].mean(), perc10_k500_r['unlearning_time'].mean(), perc10_k1000_r['unlearning_time'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)

y_mu = [perc50_k50_mu['unlearning_time'].mean(), perc50_k500_mu['unlearning_time'].mean(), perc50_k1000_mu['unlearning_time'].mean()]
y_cf = [perc50_k50_cf['unlearning_time'].mean(), perc50_k500_cf['unlearning_time'].mean(), perc50_k1000_cf['unlearning_time'].mean()]
y_r = [perc50_k50_r['unlearning_time'].mean(), perc50_k500_r['unlearning_time'].mean(), perc50_k1000_r['unlearning_time'].mean()]
Y_MU.append(y_mu)
Y_CF.append(y_cf)
Y_R.append(y_r)




# Creating figure and axes
fig, axes = plt.subplots(4, 3, figsize=(16, 14), dpi=150)

titles = ['Forget Percentage = 1%', 'Forget Percentage = 10%', 'Forget Percentage = 50%']
y_labs=['RA', 'FA', 'MIA', 'UT']

# Looping over all axes to plot data
for i in range(4):
    for j in range(3):
        ax = axes[i][j]
        # Modular
        sns.lineplot(x=x, y=Y_MU[i*3+j], marker='^', markersize=10, linewidth=2.5, label='modular', ax=ax)
        # Catastrophic
        sns.lineplot(x=x, y=Y_CF[i*3+j], marker='^', markersize=10, linewidth=2.5, label='catastrophic', ax=ax)
        # Retraining
        sns.lineplot(x=x, y=Y_R[i*3+j], marker='^', markersize=10, linewidth=2.5, label='retraining', ax=ax)

        # Setting labels and title for each subplot
        ax.set_xlabel('K',fontsize=16)
        ax.set_ylabel(y_labs[i], fontweight='bold',fontsize=16)
        if i==0:
            ax.set_title(titles[j], fontsize=16)
        ax.legend(fontsize=14)

plt.tight_layout()
plt.show()
